# %%
import pandas as pd

from diamondminer.miner import *
from diamondminer.utils import *

# %matplotlib inline

# %%
db_file = "/Users/andrijapaurevic/Desktop/QCoDeS Database Files/experiments_n45_d13_2024-07-24.db"

X_data, Y_data, Z_data = get_data_from_qcodes_db(
    db_file,
    5,
    plot=True
)

# %%
extract_bias_point(
    lb_data = X_data,
    rb_data = Y_data,
    current_data = Z_data * 1e-9,
    minAngleDeg = -60,
    maxAngleDeg = -40,
    threshold = 10,
    minLineLength = 50,
    maxLineGap= 250,
    debug=False,
    plot_results=True
)
# Out:
# [(np.float64(0.638), np.float64(0.658)),
#  (np.float64(0.613), np.float64(0.719)),
#  (np.float64(0.615), np.float64(0.676)),
#  (np.float64(0.611), np.float64(0.737))]
